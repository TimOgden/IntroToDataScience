# %% [markdown]
# # Lab 10: Correlation, Variance of Sample Means
#
# In today's lab, we will learn about [the variance of sample means](https://www.inferentialthinking.com/chapters/14/5/variability-of-the-sample-mean.html) as well as ways to understand and quantify [the association between two variables](https://www.inferentialthinking.com/chapters/15/1/correlation.html).

# %%
# Run this cell, but please don't change it.

# These lines import the Numpy and Datascience modules.
import numpy as np
from datascience import *

# These lines do some fancy plotting magic.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore', FutureWarning)

# %%
# These lines load the tests.
from client.api.notebook import Notebook
ok = Notebook('lab10.ok')
_ = ok.auth(inline=True)
# Out:
# =====================================================================
# Assignment: Correlation and Variance of Sample Means
# OK, version v1.14.15
# =====================================================================
#
# Successfully logged in as togden1@binghamton.edu

# %% [markdown]
# # 1. How Faithful is Old Faithful?
#
# (Note: clever title comes from [here](http://web.pdx.edu/~jfreder/M212/oldfaithful.pdf).)
#
# Old Faithful is a geyser in Yellowstone National Park in the central United States.  It's famous for erupting on a fairly regular schedule.  You can see a video below.

# %%
# For the curious: this is how to display a YouTube video in a
# Jupyter notebook.  The argument to YouTubeVideo is the part
# of the URL (called a "query parameter") that identifies the
# video.  For example, the full URL for this video is:
#   https://www.youtube.com/watch?v=wE8NDuzt8eg
from IPython.display import YouTubeVideo
YouTubeVideo("wE8NDuzt8eg")

# %% [markdown]
# Some of Old Faithful's eruptions last longer than others.  When it has a long eruption, there's generally a longer wait until the next eruption.
#
# If you visit Yellowstone, you might want to predict when the next eruption will happen, so you can see the rest of the park and come to see the geyser when it happens.  Today, we will use a dataset on eruption durations and waiting times to see if we can make such predictions accurately with linear regression.
#
# The dataset has one row for each observed eruption.  It includes the following columns:
# - **duration**: Eruption duration, in minutes.
# - **wait**: Time between this eruption and the next, also in minutes.
#
# Run the next cell to load the dataset.

# %%
faithful = Table.read_table("faithful.csv")
faithful
# Out:
# duration | wait
# 3.6      | 79
# 1.8      | 54
# 3.333    | 74
# 2.283    | 62
# 4.533    | 85
# 2.883    | 55
# 4.7      | 88
# 3.6      | 85
# 1.95     | 51
# 4.35     | 85
# ... (262 rows omitted)

# %% [markdown]
# We would like to use linear regression to make predictions, but that won't work well if the data aren't roughly linearly related.  To check that, we should look at the data.

# %% [markdown]
# #### Question 1
# Make a scatter plot of the data.  It's conventional to put the column we will try to predict on the vertical axis and the other column for the predictor variable on the horizontal axis. Before you start, recall what is the value that you want to predict for (wait or duration)?

# %%
faithful.scatter('duration', 'wait')

# %% [markdown]
# #### Question 2
# Look at the scatter plot. Are eruption duration and waiting time roughly linearly related?  Is the relationship positive, as we claimed earlier?  You may want to consult this [section](https://www.inferentialthinking.com/chapters/15/prediction.html) of the textbook for the definition of a linear association.

# %% [markdown]
# Yes, there is a rough linear relation between the duration and waiting time. It is positively related.

# %% [markdown]
# We're going to continue with the provisional assumption that they are linearly related, so it's reasonable to use linear regression to analyze this data.
#
# We'd next like to plot the data in standard units.  Recall that, if `nums` is an array of numbers, then
#
#     (nums - np.mean(nums)) / np.std(nums)
#
# is an array of those numbers in standard units.

# %% [markdown]
# #### Question 3
# Compute the mean and standard deviation of the eruption durations and waiting times.  **Then**, create a table called `faithful_standard` containing the eruption durations and waiting times in standard units. The two columns of this new table should be named `"duration (standard units)"` and `"wait (standard units)"`.

# %%
duration_mean = np.mean(faithful['duration'])
duration_std = np.std(faithful['duration'])
wait_mean = np.mean(faithful['wait'])
wait_std = np.std(faithful['wait'])

faithful_standard = Table().with_columns(
    "duration (standard units)", (faithful['duration'] - duration_mean) / duration_std,
    "wait (standard units)", (faithful['wait'] - wait_mean) / wait_std)
faithful_standard
# Out:
# duration (standard units) | wait (standard units)
# 0.0984989                 | 0.597123
# -1.48146                  | -1.24518
# -0.135861                 | 0.228663
# -1.0575                   | -0.655644
# 0.917443                  | 1.03928
# -0.530851                 | -1.17149
# 1.06403                   | 1.26035
# 0.0984989                 | 1.03928
# -1.3498                   | -1.46626
# 0.756814                  | 1.03928
# ... (262 rows omitted)

# %%
_ = ok.grade('q1_3')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# #### Question 4
# Plot the data again, but this time in standard units.

# %%
faithful_standard.scatter('duration (standard units)', 'wait (standard units)')

# %% [markdown]
# You'll notice that this plot looks exactly the same as the last one!  The data really are different, but the axes are scaled differently.  (The method `scatter` scales the axes so the data fill up the available space.)  So it's important to read the ticks on the axes.

# %% [markdown]
# #### Question 5
# Among the following numbers, which would you guess is closest to the correlation between eruption duration and waiting time in this dataset?
#
# * -1
# * 0
# * 1

# %% [markdown]
# 1

# %% [markdown]
# #### Question 6
# Use the formula and steps given in the book to compute the correlation `r`. Do not use an existing correlation function in provided in python.  *Hint:* Use `faithful_standard`.  This [section](https://www.inferentialthinking.com/chapters/15/1/correlation.html) on correlation explains how to do this.

# %%
r = np.mean(faithful_standard['duration (standard units)'] * faithful_standard['wait (standard units)'])
r
# Out:
# 0.9008111683218132

# %%
_ = ok.grade('q1_6')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# # 2. Variability of the Sample Mean
#
# By the Central Limit Theorem, the probability distribution of the mean of a large random sample is roughly normal. The bell curve is centered at the population mean. Some of the sample means are higher and some are lower, but the deviations from the population mean are roughly symmetric on either side, as we have seen repeatedly. Formally, probability theory shows that the sample mean is an unbiased estimate of the population mean.
#
# In our simulations, we also noticed that the means of larger samples tend to be more tightly clustered around the population mean than means of smaller samples. In this section, we will quantify the variability of the sample mean and develop a relation between the variability and the sample size.
#
# Let's take a look at the salaries of employees of the City of San Francisco in 2014. The mean salary reported by the city government was about $75463.92.

# %%
salaries = Table.read_table('sf_salaries_2014.csv').select("salary")
salaries
# Out:
# salary
# 471953
# 390112
# 339654
# 326717
# 326233
# 344187
# 311299
# 310161
# 335485
# 329391
# ... (38113 rows omitted)

# %%
salary_mean = np.mean(salaries.column('salary'))
salary_mean
# Out:
# 75463.91814023031

# %%
salaries.hist('salary', bins=np.arange(0, 300000+10000*2, 10000))
plots.scatter(salary_mean, 0, marker='^', color='red', s=100);

# %% [markdown]
# #### Question 1
#
# Clearly, the population does not follow a normal distribution. Keep that in mind as we progress through these exercises.
#
# Note also that the above data are the entire population. However, we often do not have data for the entire population in practice; instead we made inference about the population based on a random sample.
#
# Let's take random samples and look at the probability distribution of the sample mean. As usual, we will repeatly drawn random samples from the population to get an empirical approximation to this distribution.
#
# We will define a function `simulate_sample_mean` to do this, because we are going to vary the sample size later. The 4 arguments are the name of the table, the label of the column containing the variable, the sample size, and the number of simulations (that is, the number of samples re-drawn).

# %%
"""Empirical distribution of random sample means"""

def simulate_sample_mean(table, label, sample_size, repetitions):
    
    means = []

    for i in np.arange(repetitions):
        new_sample = table.sample(k=sample_size)
        new_sample_mean = np.mean(new_sample[label])
        means.append(new_sample_mean)

    sample_means = Table().with_column('Sample Means', means)
    
    # Display empirical histogram and print all relevant quantities – don't change this!
    sample_means.hist(bins=20)
    plots.xlabel('Sample Means')
    plots.title('Sample Size ' + str(sample_size))
    print("Sample size: ", sample_size)
    print("Population mean:", np.mean(table.column(label)))
    print("Average of sample means: ", np.mean(means))
    print("Population SD:", np.std(table.column(label)))
    print("SD of sample means:", np.std(means))

# %% [markdown]
# Make sure that you have done this step correctly. For example, run the first cell in Question 2 below and post a quick question on Piazza with a snapshot of the generated histogram so that others may give you a thumb up (do not post any code). If you haven't implemented it correctly, the rest of the lab won't work properly, so this step is crucial.

# %% [markdown]
# #### Question 2
#
# In the following cell, we will create a sample of size 100 from the salaries table and graph it using our new `simulate_sample_mean` function.

# %%
simulate_sample_mean(salaries, 'salary', 100, 10000) 
plots.xlim(50000, 100000)
# Out:
# Sample size:  100
# Population mean: 75463.91814023031
# Average of sample means:  75335.13963400999
# Population SD: 51697.0349864653
# SD of sample means: 5136.134711822397
# (50000, 100000)

# %% [markdown]
# In the following two cells, simulate the mean of a random sample of 400 salaries and 625 salaries, respectively. In each case, perform 10,000 repetitions of each of these processes. Don't worry about the `plots.xlim` line – it just makes sure that all of the plots have the same x-axis.

# %%
simulate_sample_mean(salaries, 'salary', 400, 10000)
plots.xlim(50000, 100000)
# Out:
# Sample size:  400
# Population mean: 75463.91814023031
# Average of sample means:  75480.33365397251
# Population SD: 51697.0349864653
# SD of sample means: 2586.510319166423
# (50000, 100000)

# %%
simulate_sample_mean(salaries, 'salary', 625, 10000)
plots.xlim(50000, 100000)
# Out:
# Sample size:  625
# Population mean: 75463.91814023031
# Average of sample means:  75465.0456615904
# Population SD: 51697.0349864653
# SD of sample means: 2081.6187981994294
# (50000, 100000)

# %% [markdown]
# Write your conclusions about what you just saw in the below cell.

# %% [markdown]
# **Conclusions:** The bootstrapping with a sample size of 625 did marginally better at approximating a normal distribution than that with a sample size of 400.

# %% [markdown]
# #### Question 3

# %% [markdown]
# Assign the variable `sampled_SD_question` to the integer corresponding to your answer to the following question:
#
# When I increase, B, the number of samples (number of repititions) that I take, for a fixed sample size, the SD of my sample means (as shown in the empirical distribution of the B sample means) will...
#
# 1. Increase
# 2. Decrease
# 3. Stay about the same
# 4. Vary widly

# %%
sampled_SD_question = 3

# %%
ok.grade('q2_3');
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# Below, we'll look at what happens when we resample from a data set, with a fixed sample size, and with different numbers of repititions. How does the distribution of the sample mean in these resamples change?

# %%
simulate_sample_mean(salaries, 'salary', 100, 500)
plots.xlim(50000, 100000)
# Out:
# Sample size:  100
# Population mean: 75463.91814023031
# Average of sample means:  75223.36636719998
# Population SD: 51697.0349864653
# SD of sample means: 5197.963991086763
# (50000, 100000)

# %%
simulate_sample_mean(salaries, 'salary', 100, 1000)
plots.xlim(50000, 100000)
# Out:
# Sample size:  100
# Population mean: 75463.91814023031
# Average of sample means:  75478.7723784
# Population SD: 51697.0349864653
# SD of sample means: 5108.636946763599
# (50000, 100000)

# %%
simulate_sample_mean(salaries, 'salary', 100, 5000)
plots.xlim(50000, 100000)
# Out:
# Sample size:  100
# Population mean: 75463.91814023031
# Average of sample means:  75436.84328656
# Population SD: 51697.0349864653
# SD of sample means: 5211.606028304679
# (50000, 100000)

# %%
simulate_sample_mean(salaries, 'salary', 100, 10000)
plots.xlim(50000, 100000)
# Out:
# Sample size:  100
# Population mean: 75463.91814023031
# Average of sample means:  75487.62653431999
# Population SD: 51697.0349864653
# SD of sample means: 5189.70017407257
# (50000, 100000)

# %% [markdown]
# What did you notice about the distribution of the sample mean in the four scenarios above?
#
# The sample mean will get closer to the population mean as the repetitions increase.

# %% [markdown]
# #### Question 4
# Let's now think about how the relationships between population SD, sample SD, and SD of sample means change with varying sample size.
#
# To make sure you know what we mean by these terms:
#  - population SD is the standard deviation of the 38123 salaries in the entire population
#  - sample SD is the standard deviation of the 100, 400, or 625 salaries, in the sample (with sample size 100, 400 or 625).
#  - SD of sample means is the standard deviation of the 500, 1000, 5000, or 10000 sample means calculated based on samples with a certain sample size (such as 100 in the examples above).
#
# Which of the following is true? Again, assign the variable `pop_vs_sample` to the integer corresponding to your answer.
#
# 1. Sample SD gets smaller with increasing sample size, SD of sample means gets smaller with increasing sample size
# 2. Sample SD gets larger with increasing sample size, SD of sample means stays the same with increasing sample size
# 3. Sample SD becomes more consistent with population SD with increasing sample size, SD of sample means gets smaller with increasing sample size
# 4. Sample SD becomes more consistent with populatoin SD with increasing sample size, SD of smaple means stays the same with increasing sample size

# %%
pop_vs_sample = 3

# %%
ok.grade('q2_4');
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# Let's see what happens: First, we calculate the population SD so that we can compare the SD of each sample to the SD of the population.

# %%
pop_sd = np.std(salaries.column("salary"))
pop_sd
# Out:
# 51697.0349864653

# %% [markdown]
# Let's then see how a small sample behaves. Run the following cells multiple times to see how the SD of the sample changes from sample to sample. Adjust the bins as necessary.

# %%
sample_10 = salaries.sample(10)
sample_10.hist("salary")
print("Sample SD: ", np.std(sample_10.column("salary")))
simulate_sample_mean(sample_10, 'salary', 10, 1000)
plots.xlim(5,120000)
plots.ylim(0, .0001);
# Out:
# Sample SD:  27301.57669400513
# Sample size:  10
# Population mean: 95730.844
# Average of sample means:  95946.16541100001
# Population SD: 27301.57669400513
# SD of sample means: 8724.567898094452

# %%
sample_200 = salaries.sample(200)
sample_200.hist("salary")
print("Sample SD: ", np.std(sample_200.column("salary")))
simulate_sample_mean(sample_200, 'salary', 200, 1000)
plots.xlim(5,100000)
plots.ylim(0, .00015);
# Out:
# Sample SD:  47001.049864730274
# Sample size:  200
# Population mean: 68936.21275
# Average of sample means:  68793.41543000001
# Population SD: 47001.049864730274
# SD of sample means: 3180.8892885013197

# %%
sample_1000 = salaries.sample(1000)
sample_1000.hist("salary")
print("Sample SD: ", np.std(sample_1000.column("salary")))
simulate_sample_mean(sample_1000, 'salary', 1000, 1000)
plots.xlim(5,100000)
plots.ylim(0, .00025);
# Out:
# Sample SD:  51255.715351938576
# Sample size:  1000
# Population mean: 73202.65712
# Average of sample means:  73247.31891481
# Population SD: 51255.715351938576
# SD of sample means: 1638.4080034521628

# %% [markdown]
# Let's illustrate this trend. Below, you will see how the average absolute error of sample SD from the population SD changes with sample size (N). Note: absolute error of sample SD from the population SD changes is the absolute difference between sample SD and the population SD.

# %%
# Don't change this cell, just run it!
sample_n_errors = make_array()
for i in np.arange(10, 200, 10):
    sample_n_errors = np.append(sample_n_errors, np.average([abs(np.std(salaries.sample(i).column("salary"))-pop_sd)
                                                      for d in np.arange(100)]))
Table().with_columns("Average absolute error in SD", sample_n_errors, "N", np.arange(10, 200, 10)).plot("N", "Average absolute error in SD")

# %% [markdown]
# You should notice that the distribution of sample means gets spiker, and that the distribution of the sample increasingly looks like the distribution of the population as we get to larger sample sizes.
#
# Is there a relationship between the sample size and absolute error in standard deviation? Identify this relationship – if you're having trouble, take a look at this [section](https://www.inferentialthinking.com/chapters/12/5/variability-of-the-sample-mean.html) in our textbook about the variability of sample means.

# %% [markdown]
# That's it! You've completed Lab 10. There weren't many tests, but there were a lot of points at which you should've stopped and understood exactly what was going on. Consult the textbook or ask the staff if you have any other questions!
#
# Be sure to
# - **run all the tests** (the next cell has a shortcut for that),
# - **Save and Checkpoint** from the `File` menu,
# - **run the last cell to submit your work**,

# %%
# For your convenience, you can run this cell to run all the tests at once!
import os
print("Running all tests...")
val = lambda q: q.startswith('q1') or q.startswith('q2_3') or q.startswith('q2_4')
_ = [ok.grade(q[:-3]) for q in os.listdir("tests") if val(q)]
print("Finished running all tests.")
# Out:
# Running all tests...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed
#
# Finished running all tests.

# %%
# Run this cell to submit your work *after* you have passed all of the test cells.
# It's ok to run this cell multiple times. Only your final submission will be scored.

_ = ok.submit()
# Out:
# Saving notebook... Saved 'lab10.ipynb'.
# Submit... 100% complete
# Submission successful for user: togden1@binghamton.edu
# URL: https://okpy.org/bu/math247-cs207/fa19/lab10/submissions/z6onj7
